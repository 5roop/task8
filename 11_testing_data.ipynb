# %%
import pandas as pd
df = pd.read_csv("transfer_10.csv")
df.loc[:, ["hashname", "human_transcript"]].sample(10)
# Out:
#                                 hashname  \
# 16515   bv67e1t69T8_12814.88-12823.3.wav
# 30639  y5LrUr3SHIg_11332.37-11352.27.wav
# 33204    -aa4kot7dUU_6398.42-6415.91.wav
# 25460    8LAI5kcBfVs_7658.83-7675.22.wav
# 9102    dfz6VqXRbmE_11159.0-11178.81.wav
# 40851    WoEEFk8lcDA_7909.43-7928.86.wav
# 13094    wN5mbIwE-4U_9720.21-9735.96.wav
# 26953     5Kq_FBO-iDk_6021.8-6039.35.wav
# 39572   MJ9sB3Mu0Sw_13121.95-13136.8.wav
# 969      5T4HXO1WsDU_7431.84-7451.82.wav
#
#                                         human_transcript
# 16515  plavo ili modro ali u sadržaju se ne mijenja a...
# 30639  ostati da ugasi svjetlo samo je pitanje koliko...
# 33204  zastupaju osobno interesi sto četrdeset jedan ...
# 25460  o ovom predmetu ne možemo razmišljati out of t...
# 9102   ljudi iz plesa iz okolice zračne luke u protek...
# 40851  na vjerojatno četirici na kanalu primijetio sa...
# 13094  to je nešto što imamo i čega se moramo pridrža...
# ...

# %%
sample = [
"5Kq_FBO-iDk_6021.8-6039.35.wav",  "dfz6VqXRbmE_11159.0-11178.81.wav",
"5T4HXO1WsDU_7431.84-7451.82.wav",  "MJ9sB3Mu0Sw_13121.95-13136.8.wav",
"8LAI5kcBfVs_7658.83-7675.22.wav" , "wN5mbIwE-4U_9720.21-9735.96.wav",
"-aa4kot7dUU_6398.42-6415.91.wav" , "WoEEFk8lcDA_7909.43-7928.86.wav",
"bv67e1t69T8_12814.88-12823.3.wav" , "y5LrUr3SHIg_11332.37-11352.27.wav",
]
pd.set_option('display.max_colwidth', -1)  # or 199
df.loc[df.hashname.isin(sample), ["hashname", "human_transcript"]]
# Out:
# /tmp/ipykernel_2706497/4260446650.py:8: FutureWarning: Passing a negative integer is deprecated in version 1.0 and will not be supported in future version. Instead, use None to not limit the column width.
#   pd.set_option('display.max_colwidth', -1)  # or 199
#                                 hashname  \
# 969    5T4HXO1WsDU_7431.84-7451.82.wav
# 9102   dfz6VqXRbmE_11159.0-11178.81.wav
# 13094  wN5mbIwE-4U_9720.21-9735.96.wav
# 16515  bv67e1t69T8_12814.88-12823.3.wav
# 25460  8LAI5kcBfVs_7658.83-7675.22.wav
# 26953  5Kq_FBO-iDk_6021.8-6039.35.wav
# 30639  y5LrUr3SHIg_11332.37-11352.27.wav
# 33204  -aa4kot7dUU_6398.42-6415.91.wav
# 39572  MJ9sB3Mu0Sw_13121.95-13136.8.wav
# 40851  WoEEFk8lcDA_7909.43-7928.86.wav
#
# ...
